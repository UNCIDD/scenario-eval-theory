# %% [markdown]
# # Evaluating Scenario Projections in the Context of Diverse Consumers

# %% [markdown]
# ## Introduction

# %% [markdown]
# [Discuss the idea of evaluating sets of projections versus just the performance of a single projection and the utility of VOI/decision theory in doing this]

# %% [markdown]
# ## Preparing versus Intervening

# %% [markdown]
# [Present the utility function and highlight two types of response]

# %% [markdown]
# ## Assessing the Value of Scenario Projections

# %% [markdown]
# [Set the context for evaluation highlighting the focus on informing the decision process as opposed to other parts of the pathway from decision to utility. We need to make an argument of how we are trying to be generic, and that the assessment can change a bit based on the quality and nature of th e"other information" that is going into a decision.]

# %% [markdown]
# ### Evaluating for preparers (a brief digression)

# %% [markdown]
# [A brief discussion of how preparers are generally interested in evaluating any projection as a forecast, in which case theory is well established, but there are exceptions.]

# %% [markdown]
# ### Potential Problem 1 - Model projections are wrong

# %% [markdown]
# [Error in projections are an obvious error. Here we note that the size of the errors that are a "problem" is dictated by the utility and cost functions, so you don't need to get it completely "wrong" in the projections to make the wrong decisions. This may be the only listed error that is based on the model projections themselves. ]

# %% [markdown]
# ### Potential Problem 2 - Scenarios do not cover adequate contrasts

# %% [markdown]
# [If scenarios/differences considered are not adequately different to identify contrasts that actually distinguish between decisions. I.e., all contrasts considered are low compared to the variance in projection intervals and cost function so that the set of scenarios themselves do not provide reasonable information. ]
